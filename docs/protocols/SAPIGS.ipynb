# %% [markdown]
# # SAP Internet Graphic Server (IGS)

# %% [markdown]
# The following subsections show a graphical representation of the main protocol packets and how to generate them.
#
# First we need to perform some setup to import the packet classes:

# %%
from pysap.SAPIGS import *
from IPython.display import display

# %% [markdown]
# ## SAP IGS packet

# %%
p = SAPIGS()
p.canvas_dump()
# Out:
# <pyx.canvas.canvas instance at 0x7f9f3be2a8c0>

# %% [markdown]
# ## SAP IGS Table packet

# %%
p = SAPIGSTable()
p.canvas_dump()
# Out:
# <pyx.canvas.canvas instance at 0x7f9f598ffbd8>
